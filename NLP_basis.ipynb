# %% [markdown]
# <a href="https://colab.research.google.com/github/NehaR1306/Data_Science/blob/main/NLP_basis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Sample data with special characters and reviews
data = {
    "review": [
        "Absolutely loved this product! 😍 Works perfectly & exceeded expectations!",
        "Worst purchase ever... 😡 Totally disappointed & waste of money!!!",
        "Great value for the price 👍 but packaging was a bit damaged 😕"
    ],
    "sentiment": ["positive", "negative", "positive"]
}

# Create dataframe
df = pd.DataFrame(data)
df
# Out:
#                                               review sentiment
# 0  Absolutely loved this product! 😍 Works perfect...  positive
# 1  Worst purchase ever... 😡 Totally disappointed ...  negative
# 2  Great value for the price 👍 but packaging was ...  positive

# %%
#step 1 : conversation to lowercase
df['lowercase']=df['review'].str.lower()
df.head()
# Out:
#                                               review sentiment  \
# 0  Absolutely loved this product! 😍 Works perfect...  positive
# 1  Worst purchase ever... 😡 Totally disappointed ...  negative
# 2  Great value for the price 👍 but packaging was ...  positive
#
#                                            lowercase
# 0  absolutely loved this product! 😍 works perfect...
# 1  worst purchase ever... 😡 totally disappointed ...
# 2  great value for the price 👍 but packaging was ...

# %%
#step2 : cleaning all the spl char      (re = regular expressions)
import re
df['clean_specials'] = df['lowercase'].apply(lambda x: re.sub(r'[^a-zA-Z\s]','',x))
df
# Out:
#                                               review sentiment  \
# 0  Absolutely loved this product! 😍 Works perfect...  positive
# 1  Worst purchase ever... 😡 Totally disappointed ...  negative
# 2  Great value for the price 👍 but packaging was ...  positive
#
#                                            lowercase  \
# 0  absolutely loved this product! 😍 works perfect...
# 1  worst purchase ever... 😡 totally disappointed ...
# 2  great value for the price 👍 but packaging was ...
#
#                                       clean_specials  \
# 0  absolutely loved this product  works perfectly...
# 1  worst purchase ever  totally disappointed  was...
# 2  great value for the price  but packaging was a...
#
#                                               tokens  \
# 0  [absolutely, loved, this, product, works, perf...
# 1  [worst, purchase, ever, totally, disappointed,...
# 2  [great, value, for, the, price, but, packaging...
#
#                                         no_stopwords  \
# 0  [absolutely, loved, product, works, perfectly,...
# 1  [worst, purchase, ever, totally, disappointed,...
# 2     [great, value, price, packaging, bit, damaged]
#
#                                              stemmed  \
# 0  [absolut, love, product, work, perfectli, exce...
# 1  [worst, purchas, ever, total, disappoint, wast...
# 2           [great, valu, price, packag, bit, damag]
#
#                                           lemmatized  \
# 0  [absolutely, loved, product, work, perfectly, ...
# 1  [worst, purchase, ever, totally, disappointed,...
# 2     [great, value, price, packaging, bit, damaged]
#
#                                        emoji_to_text
# 0  Absolutely loved this product! :smiling_face_w...
# 1  Worst purchase ever... :enraged_face: Totally ...
# 2  Great value for the price :thumbs_up: but pack...

# %%
#step3 : converting text data intlo tokens
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt_tab')
df['tokens'] = df['clean_specials'].apply(word_tokenize)
df.head()
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
#                                               review sentiment  \
# 0  Absolutely loved this product! 😍 Works perfect...  positive
# 1  Worst purchase ever... 😡 Totally disappointed ...  negative
# 2  Great value for the price 👍 but packaging was ...  positive
#
#                                            lowercase  \
# 0  absolutely loved this product! 😍 works perfect...
# 1  worst purchase ever... 😡 totally disappointed ...
# 2  great value for the price 👍 but packaging was ...
#
#                                       clean_specials  \
# 0  absolutely loved this product  works perfectly...
# 1  worst purchase ever  totally disappointed  was...
# 2  great value for the price  but packaging was a...
#
#                                               tokens
# 0  [absolutely, loved, this, product, works, perf...
# 1  [worst, purchase, ever, totally, disappointed,...
# 2  [great, value, for, the, price, but, packaging...

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
#step 4 : removing of stopwords
from nltk.corpus import stopwords
stop_words= set(stopwords.words('english'))
df['no_stopwords'] = df['tokens'].apply(lambda x: [word for word  in x if word not in stop_words])
df
# Out:
#                                               review sentiment  \
# 0  Absolutely loved this product! 😍 Works perfect...  positive
# 1  Worst purchase ever... 😡 Totally disappointed ...  negative
# 2  Great value for the price 👍 but packaging was ...  positive
#
#                                            lowercase  \
# 0  absolutely loved this product! 😍 works perfect...
# 1  worst purchase ever... 😡 totally disappointed ...
# 2  great value for the price 👍 but packaging was ...
#
#                                       clean_specials  \
# 0  absolutely loved this product  works perfectly...
# 1  worst purchase ever  totally disappointed  was...
# 2  great value for the price  but packaging was a...
#
#                                               tokens  \
# 0  [absolutely, loved, this, product, works, perf...
# 1  [worst, purchase, ever, totally, disappointed,...
# 2  [great, value, for, the, price, but, packaging...
#
#                                         no_stopwords
# 0  [absolutely, loved, product, works, perfectly,...
# 1  [worst, purchase, ever, totally, disappointed,...
# 2     [great, value, price, packaging, bit, damaged]

# %%
##step 5 : steaming remove of edges
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
df['stemmed'] = df['no_stopwords'].apply(lambda x: [stemmer.stem(word) for word in x])
df
# Out:
#                                               review sentiment  \
# 0  Absolutely loved this product! 😍 Works perfect...  positive
# 1  Worst purchase ever... 😡 Totally disappointed ...  negative
# 2  Great value for the price 👍 but packaging was ...  positive
#
#                                            lowercase  \
# 0  absolutely loved this product! 😍 works perfect...
# 1  worst purchase ever... 😡 totally disappointed ...
# 2  great value for the price 👍 but packaging was ...
#
#                                       clean_specials  \
# 0  absolutely loved this product  works perfectly...
# 1  worst purchase ever  totally disappointed  was...
# 2  great value for the price  but packaging was a...
#
#                                               tokens  \
# 0  [absolutely, loved, this, product, works, perf...
# 1  [worst, purchase, ever, totally, disappointed,...
# 2  [great, value, for, the, price, but, packaging...
#
#                                         no_stopwords  \
# 0  [absolutely, loved, product, works, perfectly,...
# 1  [worst, purchase, ever, totally, disappointed,...
# 2     [great, value, price, packaging, bit, damaged]
#
#                                              stemmed
# 0  [absolut, love, product, work, perfectli, exce...
# 1  [worst, purchas, ever, total, disappoint, wast...
# 2           [great, valu, price, packag, bit, damag]

# %%
##step 6 : lemmazating ( standardize words )
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
df['lemmatized'] = df['no_stopwords'].apply(lambda x: [lemmatizer.lemmatize(word) for word in x])
df
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
#                                               review sentiment  \
# 0  Absolutely loved this product! 😍 Works perfect...  positive
# 1  Worst purchase ever... 😡 Totally disappointed ...  negative
# 2  Great value for the price 👍 but packaging was ...  positive
#
#                                            lowercase  \
# 0  absolutely loved this product! 😍 works perfect...
# 1  worst purchase ever... 😡 totally disappointed ...
# 2  great value for the price 👍 but packaging was ...
#
#                                       clean_specials  \
# 0  absolutely loved this product  works perfectly...
# 1  worst purchase ever  totally disappointed  was...
# 2  great value for the price  but packaging was a...
#
#                                               tokens  \
# 0  [absolutely, loved, this, product, works, perf...
# 1  [worst, purchase, ever, totally, disappointed,...
# 2  [great, value, for, the, price, but, packaging...
#
#                                         no_stopwords  \
# 0  [absolutely, loved, product, works, perfectly,...
# 1  [worst, purchase, ever, totally, disappointed,...
# 2     [great, value, price, packaging, bit, damaged]
#
#                                              stemmed  \
# 0  [absolut, love, product, work, perfectli, exce...
# 1  [worst, purchas, ever, total, disappoint, wast...
# 2           [great, valu, price, packag, bit, damag]
#
#                                           lemmatized
# 0  [absolutely, loved, product, work, perfectly, ...
# 1  [worst, purchase, ever, totally, disappointed,...
# 2     [great, value, price, packaging, bit, damaged]

# %%
pip install emoji
# Out:
# Collecting emoji
#   Downloading emoji-2.15.0-py3-none-any.whl.metadata (5.7 kB)
# Downloading emoji-2.15.0-py3-none-any.whl (608 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 10.6 MB/s eta 0:00:00
# Installing collected packages: emoji
# Successfully installed emoji-2.15.0

# %%
#emoji
import emoji
df['emoji_to_text'] = df['review'].apply(lambda x: emoji.demojize(x))
# emoticons
emoticon_dict = { ":-)": "smile",":-D":"laugh",":-(": "sad"}
def replace_emoticons(text):
    for k,v in emoticon_dict.items():
        text = text.replace(k,v)
    return text

df['emoji_to_text'] = df['emoji_to_text'].apply(replace_emoticons)

#lemma
lemmatizer = WordNetLemmatizer()
df['lemmatized'] = df['no_stopwords'].apply(lambda x: [lemmatizer.lemmatize(word) for word in x])

# stemming
stmmer = PorterStemmer()
df['stemmed'] = df['lemmatized'].apply(lambda x: [stmmer.stem(word) for word in x])
df
# Out:
#                                               review sentiment  \
# 0  Absolutely loved this product! 😍 Works perfect...  positive
# 1  Worst purchase ever... 😡 Totally disappointed ...  negative
# 2  Great value for the price 👍 but packaging was ...  positive
#
#                                            lowercase  \
# 0  absolutely loved this product! 😍 works perfect...
# 1  worst purchase ever... 😡 totally disappointed ...
# 2  great value for the price 👍 but packaging was ...
#
#                                       clean_specials  \
# 0  absolutely loved this product  works perfectly...
# 1  worst purchase ever  totally disappointed  was...
# 2  great value for the price  but packaging was a...
#
#                                               tokens  \
# 0  [absolutely, loved, this, product, works, perf...
# 1  [worst, purchase, ever, totally, disappointed,...
# 2  [great, value, for, the, price, but, packaging...
#
#                                         no_stopwords  \
# 0  [absolutely, loved, product, works, perfectly,...
# 1  [worst, purchase, ever, totally, disappointed,...
# 2     [great, value, price, packaging, bit, damaged]
#
#                                              stemmed  \
# 0  [absolut, love, product, work, perfectli, exce...
# 1  [worst, purchas, ever, total, disappoint, wast...
# 2           [great, valu, price, packag, bit, damag]
#
#                                           lemmatized  \
# 0  [absolutely, loved, product, work, perfectly, ...
# 1  [worst, purchase, ever, totally, disappointed,...
# 2     [great, value, price, packaging, bit, damaged]
#
#                                        emoji_to_text
# 0  Absolutely loved this product! :smiling_face_w...
# 1  Worst purchase ever... :enraged_face: Totally ...
# 2  Great value for the price :thumbs_up: but pack...

# %%
df.columns
# Out:
# Index(['review', 'sentiment', 'lowercase', 'clean_specials', 'tokens',
#        'no_stopwords', 'stemmed', 'lemmatized', 'emoji_to_text'],
#       dtype='object')

# %% [markdown]
# countvectorizer means counting how many times it has appered
# tf = term feq

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tf = TfidfVectorizer(ngram_range=(1,2))
tf.fit(df['clean_specials'])
tf.transform(df['clean_specials']).toarray()
tf.get_feature_names_out()               ## to name the similar word contexts
# Out:
# array(['absolutely', 'absolutely loved', 'bit', 'bit damaged', 'but',
#        'but packaging', 'damaged', 'disappointed', 'disappointed waste',
#        'ever', 'ever totally', 'exceeded', 'exceeded expectations',
#        'expectations', 'for', 'for the', 'great', 'great value', 'loved',
#        'loved this', 'money', 'of', 'of money', 'packaging',
#        'packaging was', 'perfectly', 'perfectly exceeded', 'price',
#        'price but', 'product', 'product works', 'purchase',
#        'purchase ever', 'the', 'the price', 'this', 'this product',
#        'totally', 'totally disappointed', 'value', 'value for', 'was',
#        'was bit', 'waste', 'waste of', 'works', 'works perfectly',
#        'worst', 'worst purchase'], dtype=object)

# %%
### coversation of text to number
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()
cv.fit(df['clean_specials'])
cv.transform(df['clean_specials']).toarray()
tf.get_feature_names_out()
# Out:
# array(['absolutely', 'bit', 'but', 'damaged', 'disappointed', 'ever',
#        'exceeded', 'expectations', 'for', 'great', 'loved', 'money', 'of',
#        'packaging', 'perfectly', 'price', 'product', 'purchase', 'the',
#        'this', 'totally', 'value', 'was', 'waste', 'works', 'worst'],
#       dtype=object)
